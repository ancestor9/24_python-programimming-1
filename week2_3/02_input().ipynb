# %%
input('what your name?')
# Out:
# what your name?name
# 'name'

# %%
input()
# Out:
# chosang
# 'chosang'

# %%
import numpy as np

# %%
np.sum(range(100))
# Out:
# 4950

# %%
for i

# %%
print("Hello  " + input('what your name?'))
# Out:
# what your name?ewre
# Hello  ewre

# %%
# Hello 문자와 입력글자를 받아 프린트하는 입출력 프로그램
print("Hello  " + input('What is your name? ') = ' !')
# Out:
#   File "<ipython-input-35-14766822e31e>", line 2
#     print("Hello  " + input('What is your name? ') = ' !')
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# # 실전엽습  이름을 입력받아 이름의 크기를 출력하는 프로그램만들기

# %%
# input('What is your name?')
print(len('chosanggoo'))
# Out:
# 10

# %% [markdown]
# ## 구글링 'how to get a length of a string in python stack overflow'

# %%
print( len( input('What is your name?')))
# Out:
# What is your name?chosang
# 7

# %% [markdown]
# # Tony Debug tool
# ### https://thonny.org/에서 다운로드 main.py으로 파일 저장후 step by step debug

# %%
# notes
# if input was 'chosang'
# print(len('chosang'))
# print(4)

# %%
# %%writefile app.py
print("Hello, World!")
# Out:
# Writing app.py

# %%
len(1234)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ec67a52704b7> in <cell line: 1>()
# ----> 1 len(1234)
#
# TypeError: object of type 'int' has no len()

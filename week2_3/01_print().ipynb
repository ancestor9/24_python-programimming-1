# %% [markdown]
# # print()

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print('Hell Python)
# Out:
#   File "<ipython-input-24-979c4997735d>", line 1
#     print('Hell Python)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hell Python" + 1)
# Out:
#   File "<ipython-input-25-5057c5fede02>", line 1
#     print('Hell Python" + 1)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
   print('Hello Python')
# Out:
# Hello Python

# %%
print('Hell"o P"ython')
# Out:
# Hell"o P"ython

# %%
print("Hell'o P'ython")
# Out:
# Hell'o P'ython

# %%
print('Hello Python\n I am cho.')
# Out:
# Hello Python
#  I am cho.

# %%
print("Hell" + 'Python')
# Out:
# HellPython

# %%
print("Hell" +' ' + 'Python')
# Out:
# Hell Python

# %% [markdown]
# # Debugging

# %%
print('abcd)
  print('hello')
print(('abcd)')
print(('abcd')
# Out:
#   File "<ipython-input-13-05b79939ae86>", line 1
#     print('abcd)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('abcd')
  print('hello')
print(('abcd)')
print(('abcd')
# Out:
#   File "<ipython-input-15-fad76347c3d6>", line 2
#     print('hello')
#     ^
# IndentationError: unexpected indent

# %%
print('abcd')
print('hello')
print(('abcd)')
print(('abcd')
# Out:
#   File "<ipython-input-16-9062103bd84b>", line 4
#     print(('abcd')
#          ^
# SyntaxError: '(' was never closed

# %%
print('abcd')
print('hello')
print('abcd)')
print(('abcd')
# Out:
#   File "<ipython-input-18-8deb9a4d957c>", line 4
#     print(('abcd')
#                   ^
# SyntaxError: incomplete input

# %%
print('abcd')
print('hello')
print('abcd)')
print('abcd')
# Out:
# abcd
# hello
# abcd)
# abcd

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %whos
# Out:
# Interactive namespace is empty.

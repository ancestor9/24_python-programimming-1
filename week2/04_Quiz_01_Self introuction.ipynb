# %%
def greet(name, greeting='Hello'):
    print(f'{greeting}, {name}')

# %%
greet('Alice')
# Out:
# Hello, Alice

# %%
greet(name= 'Bob', greeting='Hi')
# Out:
# Hi, Bob

# %%
greet('Carol', greeting='Hey')
# Out:
# Hey, Carol

# %%
name = "Jack"
print(nama)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a0e8988db6b> in <cell line: 2>()
#       1 name = "Jack"
# ----> 2 print(nama)
#
# NameError: name 'nama' is not defined

# %%
print(name)

# %%
user name = input('Wht is your name?')
# Out:
#   File "<ipython-input-2-dd7936d020e0>", line 1
#     user name = input('Wht is your name?')
#          ^
# SyntaxError: invalid syntax

# %%
user_name = input('Wht is your name?')
# Out:
# Wht is your name?ccc

# %%
1length = len(user_name)
# Out:
#   File "<ipython-input-4-4722208fab99>", line 1
#     1length = len(user_name)
#     ^
# SyntaxError: invalid decimal literal

# %%
length1 = len(user_name)   # length2 = len(user_name)

# %%
print(length1)
# Out:
# 3

# %% [markdown]
# # 퀴즈

# %%
residence = input('사는 곳이 어디이지?')
print(residence)
# Out:
# 사는 곳이 어디이지?sss
# sss

# %%
name = input('너의 이름이 무엇이니?')
print(name)
# Out:
# 너의 이름이 무엇이니?sss
# sss

# %%
#picture = '6_i43Ud018svc5ubd1npgg69v_f7elet.jpg'
picture = '/content/111.jfif'

# %%
import PIL.Image as pilimg

# %%
pilimg.open(picture)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x318>

# %%
img = pilimg.open(picture)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x318>

# %%
import numpy as np
np.array(img)
# Out:
# array([[[216, 214, 227],
#         [216, 214, 227],
#         [216, 214, 227],
#         ...,
#         [199, 205, 229],
#         [199, 205, 229],
#         [199, 205, 229]],
#
#        [[216, 214, 227],
#         [216, 214, 227],
#         [216, 214, 227],
#         ...,
#         [199, 205, 229],
#         [199, 205, 229],
#         [199, 205, 229]],
#
#        [[216, 214, 227],
#         [216, 214, 227],
#         [216, 214, 227],
#         ...,
#         [199, 205, 229],
#         [199, 205, 229],
#         [199, 205, 229]],
#
#        ...,
#
#        [[ 27,  26,  32],
#         [ 27,  26,  32],
#         [ 26,  25,  31],
#         ...,
#         [145, 184, 215],
#         [145, 181, 215],
#         [142, 178, 214]],
#
#        [[ 26,  25,  31],
#         [ 26,  25,  31],
#         [ 26,  25,  31],
#         ...,
#         [147, 184, 213],
#         [145, 181, 215],
#         [141, 177, 213]],
#
#        [[ 26,  25,  31],
#         [ 26,  25,  31],
#         [ 26,  25,  31],
# ...

# %%
arr = np.array(img)
arr.shape
# Out:
# (318, 318, 3)

# %%
arr[:, :, 0]
# Out:
# array([[216, 216, 216, ..., 199, 199, 199],
#        [216, 216, 216, ..., 199, 199, 199],
#        [216, 216, 216, ..., 199, 199, 199],
#        ...,
#        [ 27,  27,  26, ..., 145, 145, 142],
#        [ 26,  26,  26, ..., 147, 145, 141],
#        [ 26,  26,  26, ..., 147, 145, 142]], dtype=uint8)

# %%
arr[:, :, 1]
# Out:
# array([[214, 214, 214, ..., 205, 205, 205],
#        [214, 214, 214, ..., 205, 205, 205],
#        [214, 214, 214, ..., 205, 205, 205],
#        ...,
#        [ 26,  26,  25, ..., 184, 181, 178],
#        [ 25,  25,  25, ..., 184, 181, 177],
#        [ 25,  25,  25, ..., 184, 181, 178]], dtype=uint8)

# %%
arr[:, :, 2]
# Out:
# array([[227, 227, 227, ..., 229, 229, 229],
#        [227, 227, 227, ..., 229, 229, 229],
#        [227, 227, 227, ..., 229, 229, 229],
#        ...,
#        [ 32,  32,  31, ..., 215, 215, 214],
#        [ 31,  31,  31, ..., 213, 215, 213],
#        [ 31,  31,  31, ..., 213, 215, 214]], dtype=uint8)

# %%
pilimg.open(arr[:, :, 2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3230     try:
# -> 3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-d331c5af44c4> in <cell line: 1>()
# ----> 1 pilimg.open(arr[:, :, 2])
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
# -> 3233         fp = io.BytesIO(fp.read())
#    3234         exclusive_fp = True
#    3235
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'

# %%
import matplotlib.pyplot as plt
plt.imshow(arr[:, :, 2])

# %%
for i in range(3):
    plt.imshow(arr[:, :, i])
    plt.show()

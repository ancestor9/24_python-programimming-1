# %%
input('Wht is your name?')
# Out:
# Wht is your name?cho
# 'cho'

# %%
type(1)
# Out:
# int

# %%
type('sang')
# Out:
# str

# %%
type(input('Wht is your name?'))
# Out:
# Wht is your name?cho
# str

# %%
name = input('Wht is your name?')
# Out:
# Wht is your name?cho

# %%
print(name)
# Out:
# cho

# %%
# 이름과 전화번호부 --> variable

# %%
name ='chosang'
print(name)
# Out:
# chosang

# %%
name ='sangoo'
print(name)
# Out:
# sangoo

# %%
print( len( input('Wht is your name?')))
# Out:
# Wht is your name?cho
# 3

# %%
name = input('Wht is your name?')
# Out:
# Wht is your name?cho

# %%
length = len(name)

# %%
print(length)
# Out:
# 3

# %% [markdown]
# # 실전연습_variable
# ## 두 개의 변수 바꾸기
# - 다른 3의 변수가 필요함

# %%
a = input('input a:')
b = input('input b:')
# Out:
# input a:4
# input b:3

# %%
print(a)
print(b)
# Out:
# 4
# 3

# %%
c = a

# %%
a = b

# %%
b = c

# %%
print(a)
print(b)
# Out:
# 3
# 4

# %%
# %who
# Out:
# a	 b	 c	 length	 name

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          str     3
# b          str     4
# c          str     4
# length     int     3
# name       str     cho

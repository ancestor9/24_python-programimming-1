# %% [markdown]
# # 총 2시간

# %% [markdown]
# # Quiz A.
# - 2명 이상의 키를 ','(comma)로 입력받아 가장 높은 키를 구하는 코드를 만들어라
# * max() 함수는 사용할 수 없다.

# %% [markdown]
# # Quiz B.
# - 1부터 100까지 모든 수의 합계를 구하는 코드
#
# - **for item in list_of_items:**
#     - **Do something to each item (Block 1)**
#     - **Do something to each item (Block 1)**

# %% [markdown]
# # Quiz C.
# - 1부터 100까지 모든 짝수와 홀수 합계를 구하는 코드

# %% [markdown]
# # Quiz D.
# - 1부터 100까지 모든 홀수 합계를 구하는 코드
